# %%
from cobra.io import load_matlab_model,load_json_model

from pytfa.io import load_thermoDB,                    \
                        read_lexicon, annotate_from_lexicon,            \
                        read_compartment_data, apply_compartment_data


root_dir = '/Users/joshuagoldford/Documents/github/pytfa'

import pytfa

# Load the model
cobra_model = load_json_model(root_dir + '/models/iJO1366.json')

# Load reaction DB
thermo_data = load_thermoDB(root_dir + '/data/thermo_data.thermodb')
lexicon = read_lexicon(root_dir + '/models/iJO1366/lexicon.csv')
compartment_data = read_compartment_data(root_dir + '/models/iJO1366/compartment_data.json')

# Initialize the model
tmodel = pytfa.ThermoModel(thermo_data, cobra_model)
tmodel.name = 'tutorial'

# Annotate the model
annotate_from_lexicon(tmodel, lexicon)
apply_compartment_data(tmodel, compartment_data)

## TFA conversion
tmodel.prepare()
tmodel.convert()
# Out:
# 2021-08-26 15:44:10,278 - thermomodel_None - INFO - # Model initialized with units kcal/mol and temperature 298.15 K
# 2021-08-26 15:44:10,287 - thermomodel_None - INFO - # Model preparation starting...
# 2021-08-26 15:44:12,934 - thermomodel_None - WARNING - Warning : NULL/U
# 2021-08-26 15:44:12,935 - thermomodel_None - WARNING - Warning : NULL/L
# 2021-08-26 15:44:12,935 - thermomodel_None - WARNING - Warning : NULL/L
# 2021-08-26 15:44:12,936 - thermomodel_None - WARNING - Warning : NULL/U
# 2021-08-26 15:44:12,937 - thermomodel_None - WARNING - Warning : NULL/L
# 2021-08-26 15:44:12,937 - thermomodel_None - WARNING - Warning : NULL/L
# 2021-08-26 15:44:13,277 - thermomodel_None - WARNING - Warning : NULL/U
# 2021-08-26 15:44:13,278 - thermomodel_None - WARNING - Warning : NULL/L
# 2021-08-26 15:44:13,278 - thermomodel_None - WARNING - Warning : NULL/L
# 2021-08-26 15:44:13,279 - thermomodel_None - WARNING - Warning : NULL/U
# 2021-08-26 15:44:13,280 - thermomodel_None - WARNING - Warning : NULL/L
# 2021-08-26 15:44:13,281 - thermomodel_None - WARNING - Warning : NULL/L
# 2021-08-26 15:44:13,498 - thermomodel_None - WARNING - Warning : NULL/U
# 2021-08-26 15:44:13,499 - thermomodel_None - WARNING - Warning : NULL/L
# 2021-08-26 15:44:13,499 - thermomodel_None - WARNING - Warning : NULL/L
# 2021-08-26 15:44:13,500 - thermomodel_None - WARNING - Warning : NULL/U
# 2021-08-26 15:44:13,501 - thermomodel_None - WARNING - Warning : NULL/L
# 2021-08-26 15:44:13,501 - thermomodel_None - WARNING - Warning : NULL/L
# 2021-08-26 15:44:13,580 - thermomodel_None - WARNING - Warning : NULL/U
# 2021-08-26 15:44:13,581 - thermomodel_None - WARNING - Warning : NULL/L
# 2021-08-26 15:44:13,582 - thermomodel_None - WARNING - Warning : NULL/L
# 2021-08-26 15:44:13,582 - thermomodel_None - WARNING - Warning : NULL/U
# 2021-08-26 15:44:13,583 - thermomodel_None - WARNING - Warning : NULL/L
# 2021-08-26 15:44:13,583 - thermomodel_None - WARNING - Warning : NULL/L
# 2021-08-26 15:44:13,584 - thermomodel_None - WARNING - Warning : NULL/U
# 2021-08-26 15:44:13,585 - thermomodel_None - WARNING - Warning : NULL/L
# 2021-08-26 15:44:13,586 - thermomodel_None - WARNING - Warning : NULL/L
# 2021-08-26 15:44:13,587 - thermomodel_None - WARNING - Warning : NULL/U
# 2021-08-26 15:44:13,588 - thermomodel_None - WARNING - Warning : NULL/L
# 2021-08-26 15:44:13,588 - thermomodel_None - WARNING - Warning : NULL/L
# 2021-08-26 15:44:13,590 - thermomodel_None - WARNING - Warning : NULL/U
# 2021-08-26 15:44:13,591 - thermomodel_None - WARNING - Warning : NULL/L
# 2021-08-26 15:44:13,592 - thermomodel_None - WARNING - Warning : NULL/L
# 2021-08-26 15:44:13,592 - thermomodel_None - WARNING - Warning : NULL/U
# 2021-08-26 15:44:13,593 - thermomodel_None - WARNING - Warning : NULL/L
# 2021-08-26 15:44:13,594 - thermomodel_None - WARNING - Warning : NULL/L
# 2021-08-26 15:44:13,596 - thermomodel_None - WARNING - Warning : NULL/U
# 2021-08-26 15:44:13,597 - thermomodel_None - WARNING - Warning : NULL/L
# 2021-08-26 15:44:13,597 - thermomodel_None - WARNING - Warning : NULL/L
# 2021-08-26 15:44:13,598 - thermomodel_None - WARNING - Warning : NULL/U
# 2021-08-26 15:44:13,599 - thermomodel_None - WARNING - Warning : NULL/L
# 2021-08-26 15:44:13,600 - thermomodel_None - WARNING - Warning : NULL/L
# 2021-08-26 15:44:13,835 - thermomodel_None - INFO - # Model preparation done.
# 2021-08-26 15:44:13,836 - thermomodel_None - INFO - # Model conversion starting...
# 2021-08-26 15:44:29,120 - thermomodel_None - INFO - # Model conversion done.
# 2021-08-26 15:44:29,121 - thermomodel_None - INFO - # Updating cobra_model variables...
# 2021-08-26 15:44:29,160 - thermomodel_None - INFO - # cobra_model variables are up-to-date

# %%
import pytfa

# %%
help(pytfa.optim.model.variables)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-442c8fbcc42b> in <module>
# ----> 1 help(pytfa.core.model.variables)
#
# AttributeError: module 'pytfa.core.model' has no attribute 'variables'

# %%
from pytfa.optim.variables import LogConcentration

# %%
help(tmodel.get_variables_of_type(LogConcentration)[0])
# Out:
# Help on LogConcentration in module pytfa.optim.variables object:
#
# class LogConcentration(MetaboliteVariable)
#  |  LogConcentration(metabolite, **kwargs)
#  |
#  |  Class to represent a log concentration of a enzyme
#  |
#  |  Method resolution order:
#  |      LogConcentration
#  |      MetaboliteVariable
#  |      GenericVariable
#  |      builtins.object
#  |
#  |  Data and other attributes defined here:
#  |
#  |  __abstractmethods__ = frozenset()
#  |
#  |  prefix = 'LC_'
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from MetaboliteVariable:
#  |
#  |  __init__(self, metabolite, **kwargs)
#  |      :param id_: will be used to identify the variable
#  |          (name will be a concat of this and a prefix)
#  |      :param model: the cobra.Model object
#  |      :param queue: whether or not to queue the variable for update object
#  |      :param scaling_factor: scaling factor used in self.scaled, useful for
#  |                              adimensionalisation of constraints
#  |      :param kwargs: stuff you want to pass to the variable constructor
#  |
#  |  ----------------------------------------------------------------------
#  |  Readonly properties inherited from MetaboliteVariable:
#  |
#  |  id
#  |      for cobra.thermo.DictList compatibility
#  |      :return:
#  |
#  |  metabolite
#  |
#  |  model
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from GenericVariable:
#  |
#  |  __add__(self, other)
#  |      Adding either two variables together or a variable and a numeric
#  |      results in a new variable
#  |      :param other:
#  |      :return: a new Generic Variable
#  |
#  |  __mul__(self, other)
#  |      Multiplying either two variables together or a variable and a numeric
#  |      results in a new variable
#  |      :param other:
#  |      :return: a new Generic Variable
#  |
#  |  __radd__(self, other)
#  |      Take priority on symmetric arithmetic operation
#  |      :param other:
#  |      :return:
#  |
#  |  __repr__(self)
#  |      Return repr(self).
#  |
#  |  __rmul__(self, other)
#  |      Take priority on symmetric arithmetic operation
#  |      :param other:
#  |      :return:
#  |
#  |  __rsub__(self, other)
#  |      Take priority on symmetric arithmetic operation
#  |      :param other:
#  |      :return:
#  |
#  |  __rtruediv__(self, other)
#  |      Take priority on symmetric arithmetic operation
#  |      :param other:
#  |      :return:
#  |
#  |  __sub__(self, other)
#  |      Substracting either two variables together or a variable and a numeric
#  |      results in a new variable
#  |      :param other:
#  |      :return: a new Generic Variable
#  |
#  |  __truediv__(self, other)
#  |      Dividing either two variables together or a variable and a numeric
#  |      results in a new variable
#  |      :param other:
#  |      :return: a new Generic Variable
#  |
#  |  get_interface(self, queue)
#  |      Called upon completion of __init__, initializes the value of self.var,
#  |      which is returned upon call, and stores the actual interfaced variable.
#  |
#  |      :return: instance of Variable from the problem
#  |
#  |  get_operand(self, other)
#  |      For operations, choose if the operand is a GenericVariable, in which
#  |      we return its optlang variable, or something else (presumably a numeric)
#  |      and we let optlang decide what to do
#  |
#  |      :param other:
#  |      :return:
#  |
#  |  make_name(self)
#  |      Needs to be overridden by the subclass, concats the id with a
#  |       prefix
#  |
#  |      :return: None
#  |
#  |  make_result(self, new_variable)
#  |      Returns a Sympy expression
#  |      :param new_variable:
#  |      :return:
#  |
#  |  test_consistency(self, other)
#  |      Tests whether a candidate to an operation is of the right type and is
#  |      from the same problem
#  |
#  |      :param other: an object
#  |      :return: None
#  |
#  |  ----------------------------------------------------------------------
#  |  Readonly properties inherited from GenericVariable:
#  |
#  |  __attrname__
#  |      Name the attribute the instances will have
#  |      Example: GenericVariable -> generic_variable
#  |      :return:
#  |
#  |  scaling_factor
#  |
#  |  type
#  |
#  |  unscaled
#  |      If the scaling factor of quantity X is a, it is represented by
#  |      the variable X_hat = X/a.
#  |      This returns X = a.X_hat
#  |      Useful for nondimensionalisation of variables and constraints
#  |
#  |      :return: The variable divided by its scaling factor
#  |
#  |  unscaled_value
#  |
#  |  value
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from GenericVariable:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  name
#  |
#  |  variable

# %%
tmodel.optimize()
# Out:
# <Solution 0.000 at 0x7fc5d786d940>

# %%
tmodel.LC_vars
# Out:
# {<Metabolite 10fthf_c at 0x7fc5ed324160>: -13.815510557964274 <= LC_10fthf_c <= -2.995732273553991,
#  <Metabolite 12dgr120_c at 0x7fc5ed324130>: -13.815510557964274 <= LC_12dgr120_c <= -2.995732273553991,
#  <Metabolite galctn-D_e at 0x7fc5e89f6f70>: -18.420680743952367 <= LC_galctn-D_e <= -2.3025850929940455,
#  <Metabolite galctn-L_e at 0x7fc5e89f6fa0>: -18.420680743952367 <= LC_galctn-L_e <= -2.3025850929940455,
#  <Metabolite galt_e at 0x7fc5e89f6fd0>: -18.420680743952367 <= LC_galt_e <= -2.3025850929940455,
#  <Metabolite galur_e at 0x7fc5e89ff040>: -18.420680743952367 <= LC_galur_e <= -2.3025850929940455,
#  <Metabolite gam_e at 0x7fc5e89ff070>: -18.420680743952367 <= LC_gam_e <= -2.3025850929940455,
#  ...}

# %%
help(pytfa.optim.relaxation.relax_dgo)
# Out:
# Help on function relax_dgo in module pytfa.optim.relaxation:
#
# relax_dgo(tmodel, reactions_to_ignore=(), solver=None, in_place=False)
#     :param t_tmodel:
#     :type t_tmodel: pytfa.thermo.ThermoModel:
#     :param reactions_to_ignore: Iterable of reactions that should not be relaxed
#     :param solver: solver to use (e.g. 'optlang-glpk', 'optlang-cplex',
#         'optlang-gurobi'
#     :return: a cobra_model with relaxed bounds on standard Gibbs free energy

# %%
help(pytfa.analysis.variability_analysis)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-47800448c306> in <module>
# ----> 1 help(pytfa.analysis.variability_analysis)
#
# AttributeError: module 'pytfa' has no attribute 'analysis'

# %%
# Out:
# Help on module pytfa.optim.constraints in pytfa.optim:
#
# NAME
#     pytfa.optim.constraints
#
# DESCRIPTION
#     .. module:: pytfa
#        :platform: Unix, Windows
#        :synopsis: Thermodynamics-based Flux Analysis
#
#     .. moduleauthor:: pyTFA team
#
#     Constraints declarations
#
# CLASSES
#     builtins.object
#         GenericConstraint
#             ForbiddenProfile
#             GeneConstraint
#             MetaboliteConstraint
#             ModelConstraint
#                 LinearizationConstraint
#             ReactionConstraint
#                 BackwardDeltaGCoupling
#                 BackwardDirectionCoupling
#                 DisplacementCoupling
#                 ForwardDeltaGCoupling
#                 ForwardDirectionCoupling
#                 NegativeDeltaG
#                 SimultaneousUse
#
#     class BackwardDeltaGCoupling(ReactionConstraint)
#      |  BackwardDeltaGCoupling(reaction, expr, **kwargs)
#      |
#      |  Class to represent thermodynamics coupling: DeltaG of reactions has to be
#      |  DGR > 0 for the reaction to proceed backwards
#      |  Looks like:
#      |  BU_rxn: 1000 BU_rxn - DGR_rxn < 1000
#      |
#      |  Method resolution order:
#      |      BackwardDeltaGCoupling
#      |      ReactionConstraint
#      |      GenericConstraint
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, reaction, expr, **kwargs)
#      |      :param id_: will be used to identify the variable
#      |          (name will be a concat of this and a prefix)
#      |      :param model: the cobra.Model object
#      |      :param queue: whether or not to queue the variable for update object
#      |      :param kwargs: stuff you want to pass to the variable constructor
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  prefix = 'BU_'
#      |
#      |  ----------------------------------------------------------------------
#      |  Readonly properties inherited from ReactionConstraint:
#      |
#      |  id
#      |      for cobra.thermo.DictList compatibility
#      |      :return:
#      |
#      |  model
#      |
#      |  reaction
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from GenericConstraint:
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#      |
#      |  change_expr(self, new_expr, sloppy=False)
#      |
#      |  get_interface(self, expr, queue)
#      |      Called upon completion of __init__, initializes the value of self.var,
#      |      which is returned upon call, and stores the actual interfaced variable.
#      |
#      |      :return: instance of Variable from the problem
#      |
#      |  make_name(self)
#      |      Needs to be overridden by the subclass, concats the id with a
#      |       prefix
#      |
#      |      :return: None
#      |
#      |  ----------------------------------------------------------------------
#      |  Readonly properties inherited from GenericConstraint:
#      |
#      |  __attrname__
#      |      Name the attribute the instances will have
#      |      Example: GenericConstraint -> generic_constraint
#      |      :return:
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from GenericConstraint:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  constraint
#      |
#      |  expr
#      |
#      |  name
#
#     class BackwardDirectionCoupling(ReactionConstraint)
#      |  BackwardDirectionCoupling(reaction, expr, **kwargs)
#      |
#      |  Class to represent a backward directionality coupling with thermodynamics on
#      |  reaction variables
#      |  Looks like :
#      |  UR_rxn: R_rxn - M RU_rxn < 0
#      |
#      |  Method resolution order:
#      |      BackwardDirectionCoupling
#      |      ReactionConstraint
#      |      GenericConstraint
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, reaction, expr, **kwargs)
#      |      :param id_: will be used to identify the variable
#      |          (name will be a concat of this and a prefix)
#      |      :param model: the cobra.Model object
#      |      :param queue: whether or not to queue the variable for update object
#      |      :param kwargs: stuff you want to pass to the variable constructor
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  prefix = 'UR_'
#      |
#      |  ----------------------------------------------------------------------
#      |  Readonly properties inherited from ReactionConstraint:
#      |
#      |  id
#      |      for cobra.thermo.DictList compatibility
#      |      :return:
#      |
#      |  model
#      |
#      |  reaction
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from GenericConstraint:
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#      |
#      |  change_expr(self, new_expr, sloppy=False)
#      |
#      |  get_interface(self, expr, queue)
#      |      Called upon completion of __init__, initializes the value of self.var,
#      |      which is returned upon call, and stores the actual interfaced variable.
#      |
#      |      :return: instance of Variable from the problem
#      |
#      |  make_name(self)
#      |      Needs to be overridden by the subclass, concats the id with a
#      |       prefix
#      |
#      |      :return: None
#      |
#      |  ----------------------------------------------------------------------
#      |  Readonly properties inherited from GenericConstraint:
#      |
#      |  __attrname__
#      |      Name the attribute the instances will have
#      |      Example: GenericConstraint -> generic_constraint
#      |      :return:
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from GenericConstraint:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  constraint
#      |
#      |  expr
#      |
#      |  name
#
#     class DisplacementCoupling(ReactionConstraint)
#      |  DisplacementCoupling(reaction, expr, **kwargs)
#      |
#      |  Class to represent the coupling to the thermodynamic displacement
#      |  Looks like:
#      |  Ln(Gamma) - (1/RT)*DGR_rxn = 0
#      |
#      |  Method resolution order:
#      |      DisplacementCoupling
#      |      ReactionConstraint
#      |      GenericConstraint
#      |      builtins.object
#      |
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  prefix = 'DC_'
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from ReactionConstraint:
#      |
#      |  __init__(self, reaction, expr, **kwargs)
#      |      :param id_: will be used to identify the variable
#      |          (name will be a concat of this and a prefix)
#      |      :param model: the cobra.Model object
#      |      :param queue: whether or not to queue the variable for update object
#      |      :param kwargs: stuff you want to pass to the variable constructor
#      |
#      |  ----------------------------------------------------------------------
#      |  Readonly properties inherited from ReactionConstraint:
#      |
#      |  id
#      |      for cobra.thermo.DictList compatibility
#      |      :return:
#      |
#      |  model
#      |
#      |  reaction
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from GenericConstraint:
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#      |
#      |  change_expr(self, new_expr, sloppy=False)
#      |
#      |  get_interface(self, expr, queue)
#      |      Called upon completion of __init__, initializes the value of self.var,
#      |      which is returned upon call, and stores the actual interfaced variable.
#      |
#      |      :return: instance of Variable from the problem
#      |
#      |  make_name(self)
#      |      Needs to be overridden by the subclass, concats the id with a
#      |       prefix
#      |
#      |      :return: None
#      |
#      |  ----------------------------------------------------------------------
#      |  Readonly properties inherited from GenericConstraint:
#      |
#      |  __attrname__
#      |      Name the attribute the instances will have
#      |      Example: GenericConstraint -> generic_constraint
#      |      :return:
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from GenericConstraint:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  constraint
#      |
#      |  expr
#      |
#      |  name
#
#     class ForbiddenProfile(GenericConstraint)
#      |  ForbiddenProfile(model, expr, id_, **kwargs)
#      |
#      |  Class to represent a forbidden net flux directionality profile
#      |  Looks like:
#      |  FU_rxn_1 + BU_rxn_2 + ... + FU_rxn_n <= n-1
#      |
#      |  Method resolution order:
#      |      ForbiddenProfile
#      |      GenericConstraint
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, model, expr, id_, **kwargs)
#      |      :param id_: will be used to identify the variable
#      |          (name will be a concat of this and a prefix)
#      |      :param model: the cobra.Model object
#      |      :param queue: whether or not to queue the variable for update object
#      |      :param kwargs: stuff you want to pass to the variable constructor
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  prefix = 'FP_'
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from GenericConstraint:
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#      |
#      |  change_expr(self, new_expr, sloppy=False)
#      |
#      |  get_interface(self, expr, queue)
#      |      Called upon completion of __init__, initializes the value of self.var,
#      |      which is returned upon call, and stores the actual interfaced variable.
#      |
#      |      :return: instance of Variable from the problem
#      |
#      |  make_name(self)
#      |      Needs to be overridden by the subclass, concats the id with a
#      |       prefix
#      |
#      |      :return: None
#      |
#      |  ----------------------------------------------------------------------
#      |  Readonly properties inherited from GenericConstraint:
#      |
#      |  __attrname__
#      |      Name the attribute the instances will have
#      |      Example: GenericConstraint -> generic_constraint
#      |      :return:
#      |
#      |  id
#      |      for cobra.thermo.DictList compatibility
#      |      :return:
#      |
#      |  model
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from GenericConstraint:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  constraint
#      |
#      |  expr
#      |
#      |  name
#
#     class ForwardDeltaGCoupling(ReactionConstraint)
#      |  ForwardDeltaGCoupling(reaction, expr, **kwargs)
#      |
#      |  Class to represent thermodynamics coupling: DeltaG of reactions has to be
#      |  DGR < 0 for the reaction to proceed forwards
#      |  Looks like:
#      |  FU_rxn: 1000 FU_rxn + DGR_rxn < 1000
#      |
#      |  Method resolution order:
#      |      ForwardDeltaGCoupling
#      |      ReactionConstraint
#      |      GenericConstraint
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, reaction, expr, **kwargs)
#      |      :param id_: will be used to identify the variable
#      |          (name will be a concat of this and a prefix)
#      |      :param model: the cobra.Model object
#      |      :param queue: whether or not to queue the variable for update object
#      |      :param kwargs: stuff you want to pass to the variable constructor
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  prefix = 'FU_'
#      |
#      |  ----------------------------------------------------------------------
#      |  Readonly properties inherited from ReactionConstraint:
#      |
#      |  id
#      |      for cobra.thermo.DictList compatibility
#      |      :return:
#      |
#      |  model
#      |
#      |  reaction
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from GenericConstraint:
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#      |
#      |  change_expr(self, new_expr, sloppy=False)
#      |
#      |  get_interface(self, expr, queue)
#      |      Called upon completion of __init__, initializes the value of self.var,
#      |      which is returned upon call, and stores the actual interfaced variable.
#      |
#      |      :return: instance of Variable from the problem
#      |
#      |  make_name(self)
#      |      Needs to be overridden by the subclass, concats the id with a
#      |       prefix
#      |
#      |      :return: None
#      |
#      |  ----------------------------------------------------------------------
#      |  Readonly properties inherited from GenericConstraint:
#      |
#      |  __attrname__
#      |      Name the attribute the instances will have
#      |      Example: GenericConstraint -> generic_constraint
#      |      :return:
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from GenericConstraint:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  constraint
#      |
#      |  expr
#      |
#      |  name
#
#     class ForwardDirectionCoupling(ReactionConstraint)
#      |  ForwardDirectionCoupling(reaction, expr, **kwargs)
#      |
#      |  Class to represent a forward directionality coupling with thermodynamics on
#      |  reaction variables
#      |  Looks like :
#      |  UF_rxn: F_rxn - M FU_rxn < 0
#      |
#      |  Method resolution order:
#      |      ForwardDirectionCoupling
#      |      ReactionConstraint
#      |      GenericConstraint
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, reaction, expr, **kwargs)
#      |      :param id_: will be used to identify the variable
#      |          (name will be a concat of this and a prefix)
#      |      :param model: the cobra.Model object
#      |      :param queue: whether or not to queue the variable for update object
#      |      :param kwargs: stuff you want to pass to the variable constructor
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  prefix = 'UF_'
#      |
#      |  ----------------------------------------------------------------------
#      |  Readonly properties inherited from ReactionConstraint:
#      |
#      |  id
#      |      for cobra.thermo.DictList compatibility
#      |      :return:
#      |
#      |  model
#      |
#      |  reaction
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from GenericConstraint:
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#      |
#      |  change_expr(self, new_expr, sloppy=False)
#      |
#      |  get_interface(self, expr, queue)
#      |      Called upon completion of __init__, initializes the value of self.var,
#      |      which is returned upon call, and stores the actual interfaced variable.
#      |
#      |      :return: instance of Variable from the problem
#      |
#      |  make_name(self)
#      |      Needs to be overridden by the subclass, concats the id with a
#      |       prefix
#      |
#      |      :return: None
#      |
#      |  ----------------------------------------------------------------------
#      |  Readonly properties inherited from GenericConstraint:
#      |
#      |  __attrname__
#      |      Name the attribute the instances will have
#      |      Example: GenericConstraint -> generic_constraint
#      |      :return:
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from GenericConstraint:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  constraint
#      |
#      |  expr
#      |
#      |  name
#
#     class GeneConstraint(GenericConstraint)
#      |  GeneConstraint(gene, expr, **kwargs)
#      |
#      |  Class to represent a variable attached to a enzyme
#      |
#      |  Method resolution order:
#      |      GeneConstraint
#      |      GenericConstraint
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, gene, expr, **kwargs)
#      |      :param id_: will be used to identify the variable
#      |          (name will be a concat of this and a prefix)
#      |      :param model: the cobra.Model object
#      |      :param queue: whether or not to queue the variable for update object
#      |      :param kwargs: stuff you want to pass to the variable constructor
#      |
#      |  ----------------------------------------------------------------------
#      |  Readonly properties defined here:
#      |
#      |  gene
#      |
#      |  id
#      |      for cobra.thermo.DictList compatibility
#      |      :return:
#      |
#      |  model
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  prefix = 'GC_'
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from GenericConstraint:
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#      |
#      |  change_expr(self, new_expr, sloppy=False)
#      |
#      |  get_interface(self, expr, queue)
#      |      Called upon completion of __init__, initializes the value of self.var,
#      |      which is returned upon call, and stores the actual interfaced variable.
#      |
#      |      :return: instance of Variable from the problem
#      |
#      |  make_name(self)
#      |      Needs to be overridden by the subclass, concats the id with a
#      |       prefix
#      |
#      |      :return: None
#      |
#      |  ----------------------------------------------------------------------
#      |  Readonly properties inherited from GenericConstraint:
#      |
#      |  __attrname__
#      |      Name the attribute the instances will have
#      |      Example: GenericConstraint -> generic_constraint
#      |      :return:
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from GenericConstraint:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  constraint
#      |
#      |  expr
#      |
#      |  name
#
#     class GenericConstraint(builtins.object)
#      |  GenericConstraint(expr, id_='', model=None, hook=None, queue=False, **kwargs)
#      |
#      |  Class to represent a generic constraint. The purpose is that the interface
#      |   is instantiated on initialization, to follow the type of interface used
#      |   by the problem, and avoid incompatibilities in optlang
#      |
#      |  Attributes:
#      |
#      |      :id: Used for DictList comprehension. Usually points back at a
#      |      enzyme or reaction id for ease of linking. Should be unique given
#      |      a constraint type.
#      |      :name: Should be a concatenation of the id and a prefix that is
#      |      specific to the variable type. will be used to address the constraint at
#      |      the solver level, and hence should be unique in the whole cobra_model
#      |      :expr: the expression of the constraint (sympy.Expression subtype)
#      |      :cobra_model: the cobra_model hook.
#      |      :constraint: links directly to the cobra_model representation of tbe constraint
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, expr, id_='', model=None, hook=None, queue=False, **kwargs)
#      |      :param id_: will be used to identify the variable
#      |          (name will be a concat of this and a prefix)
#      |      :param model: the cobra.Model object
#      |      :param queue: whether or not to queue the variable for update object
#      |      :param kwargs: stuff you want to pass to the variable constructor
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#      |
#      |  change_expr(self, new_expr, sloppy=False)
#      |
#      |  get_interface(self, expr, queue)
#      |      Called upon completion of __init__, initializes the value of self.var,
#      |      which is returned upon call, and stores the actual interfaced variable.
#      |
#      |      :return: instance of Variable from the problem
#      |
#      |  make_name(self)
#      |      Needs to be overridden by the subclass, concats the id with a
#      |       prefix
#      |
#      |      :return: None
#      |
#      |  ----------------------------------------------------------------------
#      |  Readonly properties defined here:
#      |
#      |  __attrname__
#      |      Name the attribute the instances will have
#      |      Example: GenericConstraint -> generic_constraint
#      |      :return:
#      |
#      |  id
#      |      for cobra.thermo.DictList compatibility
#      |      :return:
#      |
#      |  model
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  constraint
#      |
#      |  expr
#      |
#      |  name
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  prefix = NotImplemented
#
#     class LinearizationConstraint(ModelConstraint)
#      |  LinearizationConstraint(model, expr, id_, **kwargs)
#      |
#      |  Class to represent a variable attached to a reaction
#      |
#      |  Method resolution order:
#      |      LinearizationConstraint
#      |      ModelConstraint
#      |      GenericConstraint
#      |      builtins.object
#      |
#      |  Static methods defined here:
#      |
#      |  from_constraints(cons, model)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  prefix = 'LC_'
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from ModelConstraint:
#      |
#      |  __init__(self, model, expr, id_, **kwargs)
#      |      :param id_: will be used to identify the variable
#      |          (name will be a concat of this and a prefix)
#      |      :param model: the cobra.Model object
#      |      :param queue: whether or not to queue the variable for update object
#      |      :param kwargs: stuff you want to pass to the variable constructor
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from GenericConstraint:
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#      |
#      |  change_expr(self, new_expr, sloppy=False)
#      |
#      |  get_interface(self, expr, queue)
#      |      Called upon completion of __init__, initializes the value of self.var,
#      |      which is returned upon call, and stores the actual interfaced variable.
#      |
#      |      :return: instance of Variable from the problem
#      |
#      |  make_name(self)
#      |      Needs to be overridden by the subclass, concats the id with a
#      |       prefix
#      |
#      |      :return: None
#      |
#      |  ----------------------------------------------------------------------
#      |  Readonly properties inherited from GenericConstraint:
#      |
#      |  __attrname__
#      |      Name the attribute the instances will have
#      |      Example: GenericConstraint -> generic_constraint
#      |      :return:
#      |
#      |  id
#      |      for cobra.thermo.DictList compatibility
#      |      :return:
#      |
#      |  model
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from GenericConstraint:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  constraint
#      |
#      |  expr
#      |
#      |  name
#
#     class MetaboliteConstraint(GenericConstraint)
#      |  MetaboliteConstraint(metabolite, expr, **kwargs)
#      |
#      |  Class to represent a variable attached to a enzyme
#      |
#      |  Method resolution order:
#      |      MetaboliteConstraint
#      |      GenericConstraint
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, metabolite, expr, **kwargs)
#      |      :param id_: will be used to identify the variable
#      |          (name will be a concat of this and a prefix)
#      |      :param model: the cobra.Model object
#      |      :param queue: whether or not to queue the variable for update object
#      |      :param kwargs: stuff you want to pass to the variable constructor
#      |
#      |  ----------------------------------------------------------------------
#      |  Readonly properties defined here:
#      |
#      |  id
#      |      for cobra.thermo.DictList compatibility
#      |      :return:
#      |
#      |  metabolite
#      |
#      |  model
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  prefix = 'MC_'
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from GenericConstraint:
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#      |
#      |  change_expr(self, new_expr, sloppy=False)
#      |
#      |  get_interface(self, expr, queue)
#      |      Called upon completion of __init__, initializes the value of self.var,
#      |      which is returned upon call, and stores the actual interfaced variable.
#      |
#      |      :return: instance of Variable from the problem
#      |
#      |  make_name(self)
#      |      Needs to be overridden by the subclass, concats the id with a
#      |       prefix
#      |
#      |      :return: None
#      |
#      |  ----------------------------------------------------------------------
#      |  Readonly properties inherited from GenericConstraint:
#      |
#      |  __attrname__
#      |      Name the attribute the instances will have
#      |      Example: GenericConstraint -> generic_constraint
#      |      :return:
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from GenericConstraint:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  constraint
#      |
#      |  expr
#      |
#      |  name
#
#     class ModelConstraint(GenericConstraint)
#      |  ModelConstraint(model, expr, id_, **kwargs)
#      |
#      |  Class to represent a variable attached to the model
#      |
#      |  Method resolution order:
#      |      ModelConstraint
#      |      GenericConstraint
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, model, expr, id_, **kwargs)
#      |      :param id_: will be used to identify the variable
#      |          (name will be a concat of this and a prefix)
#      |      :param model: the cobra.Model object
#      |      :param queue: whether or not to queue the variable for update object
#      |      :param kwargs: stuff you want to pass to the variable constructor
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  prefix = 'MODC_'
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from GenericConstraint:
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#      |
#      |  change_expr(self, new_expr, sloppy=False)
#      |
#      |  get_interface(self, expr, queue)
#      |      Called upon completion of __init__, initializes the value of self.var,
#      |      which is returned upon call, and stores the actual interfaced variable.
#      |
#      |      :return: instance of Variable from the problem
#      |
#      |  make_name(self)
#      |      Needs to be overridden by the subclass, concats the id with a
#      |       prefix
#      |
#      |      :return: None
#      |
#      |  ----------------------------------------------------------------------
#      |  Readonly properties inherited from GenericConstraint:
#      |
#      |  __attrname__
#      |      Name the attribute the instances will have
#      |      Example: GenericConstraint -> generic_constraint
#      |      :return:
#      |
#      |  id
#      |      for cobra.thermo.DictList compatibility
#      |      :return:
#      |
#      |  model
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from GenericConstraint:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  constraint
#      |
#      |  expr
#      |
#      |  name
#
#     class NegativeDeltaG(ReactionConstraint)
#      |  NegativeDeltaG(reaction, expr, **kwargs)
#      |
#      |  Class to represent thermodynamics constraints.
#      |
#      |  G: - DGR_rxn + DGoRerr_Rxn + RT * StoichCoefProd1 * LC_prod1
#      |     + RT * StoichCoefProd2 * LC_prod2
#      |     + RT * StoichCoefSub1 * LC_subs1
#      |     + RT * StoichCoefSub2 * LC_subs2
#      |     - ...
#      |   = 0
#      |
#      |  Method resolution order:
#      |      NegativeDeltaG
#      |      ReactionConstraint
#      |      GenericConstraint
#      |      builtins.object
#      |
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  prefix = 'G_'
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from ReactionConstraint:
#      |
#      |  __init__(self, reaction, expr, **kwargs)
#      |      :param id_: will be used to identify the variable
#      |          (name will be a concat of this and a prefix)
#      |      :param model: the cobra.Model object
#      |      :param queue: whether or not to queue the variable for update object
#      |      :param kwargs: stuff you want to pass to the variable constructor
#      |
#      |  ----------------------------------------------------------------------
#      |  Readonly properties inherited from ReactionConstraint:
#      |
#      |  id
#      |      for cobra.thermo.DictList compatibility
#      |      :return:
#      |
#      |  model
#      |
#      |  reaction
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from GenericConstraint:
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#      |
#      |  change_expr(self, new_expr, sloppy=False)
#      |
#      |  get_interface(self, expr, queue)
#      |      Called upon completion of __init__, initializes the value of self.var,
#      |      which is returned upon call, and stores the actual interfaced variable.
#      |
#      |      :return: instance of Variable from the problem
#      |
#      |  make_name(self)
#      |      Needs to be overridden by the subclass, concats the id with a
#      |       prefix
#      |
#      |      :return: None
#      |
#      |  ----------------------------------------------------------------------
#      |  Readonly properties inherited from GenericConstraint:
#      |
#      |  __attrname__
#      |      Name the attribute the instances will have
#      |      Example: GenericConstraint -> generic_constraint
#      |      :return:
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from GenericConstraint:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  constraint
#      |
#      |  expr
#      |
#      |  name
#
#     class ReactionConstraint(GenericConstraint)
#      |  ReactionConstraint(reaction, expr, **kwargs)
#      |
#      |  Class to represent a variable attached to a reaction
#      |
#      |  Method resolution order:
#      |      ReactionConstraint
#      |      GenericConstraint
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, reaction, expr, **kwargs)
#      |      :param id_: will be used to identify the variable
#      |          (name will be a concat of this and a prefix)
#      |      :param model: the cobra.Model object
#      |      :param queue: whether or not to queue the variable for update object
#      |      :param kwargs: stuff you want to pass to the variable constructor
#      |
#      |  ----------------------------------------------------------------------
#      |  Readonly properties defined here:
#      |
#      |  id
#      |      for cobra.thermo.DictList compatibility
#      |      :return:
#      |
#      |  model
#      |
#      |  reaction
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  prefix = 'RC_'
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from GenericConstraint:
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#      |
#      |  change_expr(self, new_expr, sloppy=False)
#      |
#      |  get_interface(self, expr, queue)
#      |      Called upon completion of __init__, initializes the value of self.var,
#      |      which is returned upon call, and stores the actual interfaced variable.
#      |
#      |      :return: instance of Variable from the problem
#      |
#      |  make_name(self)
#      |      Needs to be overridden by the subclass, concats the id with a
#      |       prefix
#      |
#      |      :return: None
#      |
#      |  ----------------------------------------------------------------------
#      |  Readonly properties inherited from GenericConstraint:
#      |
#      |  __attrname__
#      |      Name the attribute the instances will have
#      |      Example: GenericConstraint -> generic_constraint
#      |      :return:
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from GenericConstraint:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  constraint
#      |
#      |  expr
#      |
#      |  name
#
#     class SimultaneousUse(ReactionConstraint)
#      |  SimultaneousUse(reaction, expr, **kwargs)
#      |
#      |  Class to represent a simultaneous use constraint on reaction variables
#      |  Looks like:
#      |  SU_rxn: FU_rxn + BU_rxn <= 1
#      |
#      |  Method resolution order:
#      |      SimultaneousUse
#      |      ReactionConstraint
#      |      GenericConstraint
#      |      builtins.object
#      |
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  prefix = 'SU_'
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from ReactionConstraint:
#      |
#      |  __init__(self, reaction, expr, **kwargs)
#      |      :param id_: will be used to identify the variable
#      |          (name will be a concat of this and a prefix)
#      |      :param model: the cobra.Model object
#      |      :param queue: whether or not to queue the variable for update object
#      |      :param kwargs: stuff you want to pass to the variable constructor
#      |
#      |  ----------------------------------------------------------------------
#      |  Readonly properties inherited from ReactionConstraint:
#      |
#      |  id
#      |      for cobra.thermo.DictList compatibility
#      |      :return:
#      |
#      |  model
#      |
#      |  reaction
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from GenericConstraint:
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#      |
#      |  change_expr(self, new_expr, sloppy=False)
#      |
#      |  get_interface(self, expr, queue)
#      |      Called upon completion of __init__, initializes the value of self.var,
#      |      which is returned upon call, and stores the actual interfaced variable.
#      |
#      |      :return: instance of Variable from the problem
#      |
#      |  make_name(self)
#      |      Needs to be overridden by the subclass, concats the id with a
#      |       prefix
#      |
#      |      :return: None
#      |
#      |  ----------------------------------------------------------------------
#      |  Readonly properties inherited from GenericConstraint:
#      |
#      |  __attrname__
#      |      Name the attribute the instances will have
#      |      Example: GenericConstraint -> generic_constraint
#      |      :return:
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from GenericConstraint:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  constraint
#      |
#      |  expr
#      |
#      |  name
#
# FILE
#     /Users/joshuagoldford/opt/miniconda3/envs/coenzymes/lib/python3.8/site-packages/pytfa/optim/constraints.py

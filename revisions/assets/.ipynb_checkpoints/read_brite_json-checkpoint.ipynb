# %%
import json
import pandas as pd

# %%
with open('ec_brite.json','r') as jsonFile:
    ec_brite =json.load(jsonFile)

# %%
list(ec_brite)
# Out:
# ['name', 'children']

# %%
EC_data_struct = {'ec': [], 'ec1': [], 'ec2': [] , 'ec3': []}

for i in range(len(ec_brite['children'])):
    first_level = ec_brite['children'][i]['name']
    for j in range(len(ec_brite['children'][i]['children'])):
        second_level = ec_brite['children'][i]['children'][j]['name']
        for k in range(len(ec_brite['children'][i]['children'][j]['children'])):
            third_level = ec_brite['children'][i]['children'][j]['children'][k]['name']
            ec_code = third_level.split(' ')[0]
            EC_data_struct['ec'].append(ec_code)
            EC_data_struct['ec1'].append(first_level)
            EC_data_struct['ec2'].append(second_level)
            EC_data_struct['ec3'].append(third_level)

# %%
pd.DataFrame(EC_data_struct).set_index('ec').to_csv('ec3_descriptions.csv')

# %%
ecdf = pd.DataFrame(EC_data_struct).set_index('ec')

# %%
#ec3_femn = pd.read_csv('FeMn.cofactors.24Feb2021.csv',index_col=0)
ec3_femn = pd.read_csv('FeMnZn.cofactors.v2.01Mar2021.csv',index_col=0)

# %%
ec3_femn
# Out:
#        ec3      cofactor                                            enzymes
# 0    1.1.1            Mn  1.1.1.41;1.1.1.42;1.1.1.84;1.1.1.93;1.1.1.267;...
# 1    1.1.1            Zn  1.1.1.1;1.1.1.2;1.1.1.251;1.1.1.261;1.1.1.284;...
# 2    1.1.3            Fe                                           1.1.3.18
# 3    1.1.3            Mn                                           1.1.3.19
# 4    1.1.5  FeS (4Fe-4S)                                            1.1.5.6
# ..     ...           ...                                                ...
# 257  6.3.4            Fe                                           6.3.4.24
# 258  6.3.4            Mn                                           6.3.4.24
# 259  6.3.4            Zn                                  6.3.4.20;6.3.4.24
# 260  6.4.1            Mn                                            6.4.1.1
# 261  6.4.1            Zn                                            6.4.1.1
#
# [262 rows x 3 columns]

# %%
ec3_femn.columns = ['EC','Cofactor','Enzymes']

# %%
#ecdf

# %%
ec_df = ec3_femn.set_index('EC').join(ecdf)

# %%
ec_df
# Out:
#            Cofactor                                            Enzymes  \
# 1.1.1            Mn  1.1.1.41;1.1.1.42;1.1.1.84;1.1.1.93;1.1.1.267;...
# 1.1.1            Zn  1.1.1.1;1.1.1.2;1.1.1.251;1.1.1.261;1.1.1.284;...
# 1.1.3            Fe                                           1.1.3.18
# 1.1.3            Mn                                           1.1.3.19
# 1.1.5  FeS (4Fe-4S)                                            1.1.5.6
# ...             ...                                                ...
# 6.3.4            Fe                                           6.3.4.24
# 6.3.4            Mn                                           6.3.4.24
# 6.3.4            Zn                                  6.3.4.20;6.3.4.24
# 6.4.1            Mn                                            6.4.1.1
# 6.4.1            Zn                                            6.4.1.1
#
#                       ec1                                       ec2  \
# ...

# %%
ec_df = ec_df[['ec1','ec2','ec3','Enzymes','Cofactor']]

# %%
ec_df['ec1'].apply(lambda x: str(x).replace('\d* ',''))
# Out:
# 1.1.1    1. Oxidoreductases
# 1.1.1    1. Oxidoreductases
# 1.1.3    1. Oxidoreductases
# 1.1.3    1. Oxidoreductases
# 1.1.5    1. Oxidoreductases
#                 ...
# 6.3.4            6. Ligases
# 6.3.4            6. Ligases
# 6.3.4            6. Ligases
# 6.4.1            6. Ligases
# 6.4.1            6. Ligases
# Name: ec1, Length: 262, dtype: object

# %%
import re

# %%
ec_df['ec1'] = ec_df['ec1'].apply(lambda x: re.sub('\d*. ','',str(x)))

# %%
ec_df.to_csv('FeMnZn.cofactors.ec_descrip.v2.01Mar2021.csv')

# %%
ec_df[ec_df['Cofactor'].isin(['Zn'])]
# Out:
#                      ec1                                                ec2  \
# 1.1.1    Oxidoreductases           1.1  Acting on the CH-OH group of donors
# 1.1.99   Oxidoreductases           1.1  Acting on the CH-OH group of donors
# 1.13.11  Oxidoreductases  1.13  Acting on single donors with incorporati...
# 1.14.99  Oxidoreductases  1.14  Acting on paired donors, with incorporat...
# 1.15.1   Oxidoreductases             1.15  Acting on superoxide as acceptor
# 1.2.7    Oxidoreductases  1.2  Acting on the aldehyde or oxo group of do...
# 1.2.98   Oxidoreductases  1.2  Acting on the aldehyde or oxo group of do...
# 1.3.1    Oxidoreductases           1.3  Acting on the CH-CH group of donors
# 1.5.7    Oxidoreductases           1.5  Acting on the CH-NH group of donors
# 1.6.5    Oxidoreductases                       1.6  Acting on NADH or NADPH
# 1.8.4    Oxidoreductases            1.8  Acting on a sulfur group of donors
# ...
